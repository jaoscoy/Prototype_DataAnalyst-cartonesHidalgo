# %% [markdown]
# # Consumo de materia prima

# %% [markdown]
# Uno de los principales problemas de las operaciones son los problemas derivados del retraso en la producción y entregas tardias lo cual a muchos clientes los desalienta a comprar volumenes más grandes. Los retrasos en producción pueden reducirse considerando la materia prima necesaria desde antes para solicitarla con anticipación y agilizar el tiempo de entrega.
#
# Con la información que tenemos en este momento, es posible visualizar el consumo en m2 requerido en cada mes para identificar tendencias y tomar precauciones en inventario.

# %%
# %matplotlib inline
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
# Importamos los archivos csv originales

df = pd.read_csv('material.csv')
columns = pd.read_csv('columns.csv')
df.columns
# Out:
# Index(['Unnamed: 0', 'foliointerno', '_id', 'Usuario.razonSocial',
#        'Productos.idLocal', 'Productos.unidades', 'Productos.cantidad',
#        'Productos.importe', 'Especificaciones.estructura',
#        'Especificaciones.tipo', 'Especificaciones.calibreECT',
#        'Especificaciones.caraExterior', 'Especificaciones.largo',
#        'Especificaciones.ancho', 'Especificaciones.alto',
#        'Especificaciones.tipoUnion', 'Especificaciones.suaje',
#        'Productos.precioUnitario', 'precios.precioGeneralm2', 'fechaEmision',
#        'Especificaciones.longitudLamina', 'Especificaciones.anchoLamina',
#        'areaM2', 'precioListaMillares', 'areaM2total'],
#       dtype='object')

# %%
# Para poder utilizar la columna 'fechaEmision' como un indice debemos convertirla a un formato de fecha

df['fechaEmision'] = pd.to_datetime(df['fechaEmision'])

# %% [markdown]
# La agrupación debe considerar el calibre ya con base a la especificación se compra la lamina de material

# %%
# Realizamos la agrupación por usuario y especificación sumando la cantidad total en m2  el mes y año en cada registro


df['fechaEmision'] = pd.to_datetime(df['fechaEmision'])
ventasCliente = df.groupby([df['fechaEmision'].dt.year, 'Especificaciones.calibreECT',df['fechaEmision'].dt.month])['areaM2total'].sum()
ventasCliente
# Out:
# fechaEmision  Especificaciones.calibreECT  fechaEmision
# 2017          26                           10               1682.000
#                                            11               1682.000
#                                            12               3364.000
#               32                           9               12060.560
#                                            10              14336.355
#                                                              ...
# 2020          36                           1               11028.706
#                                            2                6318.450
#                                            9                4514.769
#                                            10               8756.365
#               38                           10               2429.375
# Name: areaM2total, Length: 92, dtype: float64

# %%
# Desapilamos el dataframe con el metodo .unstack() para visualizar el material suministrado por año por cliente 
# convirtiendo los NaN resultado de productos no comprados por los clientes en 0

ventasClienteTotal = ventasCliente.unstack(1).fillna(0)
ventasClienteTotal
# Out:
# Especificaciones.calibreECT        23       26          29          32  \
# fechaEmision fechaEmision
# 2017         9                  0.000     0.00      0.0000  12060.5600
#              10                 0.000  1682.00      0.0000  14336.3550
#              11                 0.000  1682.00      0.0000  14336.3550
#              12                 0.000  3364.00      0.0000  28672.7100
# 2018         1                  0.000  1682.00      0.0000  14336.3550
#              2                  0.000  1682.00      0.0000  14336.3550
#              3                  0.000  3364.00      0.0000  40733.2700
#              4                  0.000  1682.00      0.0000  14336.3550
#              5                  0.000  3364.00      0.0000  28672.7100
#              6                  0.000  1682.00      0.0000  14336.3550
#              7                  0.000  3364.00      0.0000  28672.7100
#              8                  0.000  1682.00      0.0000  14336.3550
#              9                  0.000  3364.00      0.0000  40733.2700
#              10                 0.000  1682.00      0.0000  14336.3550
#              11                 0.000  3364.00      0.0000  28672.7100
#              12                 0.000  1682.00      0.0000  14336.3550
# 2019         1                  0.000  1682.00      0.0000  14336.3550
#              2                  0.000  3364.00      0.0000  28672.7100
#              3                  0.000  1682.00      0.0000  26396.9150
#              4                  0.000  3364.00      0.0000  28672.7100
#              5                  0.000  1682.00      0.0000  14336.3550
#              6                  0.000  3364.00      0.0000  28672.7100
#              7                  0.000  1682.00      0.0000  14336.3550
#              8                  0.000  3364.00      0.0000  28672.7100
#              9                  0.000  1682.00      0.0000  26396.9150
#              10                 0.000  1682.00      0.0000  14336.3550
#              11                 0.000  3869.85   5018.7420  29480.1675
#              12                 0.000  1682.00      0.0000  14336.3550
# 2020         1                  0.000  3364.00  22153.7505  34926.9440
#              2                  0.000  1682.00   4270.2305  18004.7715
#              3                  0.000  3364.00      0.0000  40733.2700
#              4                  0.000  1682.00   2410.0170  14336.3550
#              5                  0.000  3364.00      0.0000  28672.7100
#              6                  0.000  1682.00   1169.6360  17566.1850
#              7                  0.000  3869.85   1421.1160  32309.7350
#              8                  0.000  1682.00      0.0000  16417.8405
#              9                  0.000  1682.00  13450.5295  25254.5461
#              10              7695.515  3364.00   1259.2400  33378.8515
#              11                 0.000     0.00   4516.2000  53269.3640
#
# Especificaciones.calibreECT         36        38
# fechaEmision fechaEmision
# 2017         9                   0.000     0.000
#              10                  0.000     0.000
#              11                  0.000     0.000
#              12                  0.000     0.000
# 2018         1                   0.000     0.000
#              2                   0.000     0.000
#              3                   0.000     0.000
#              4                   0.000     0.000
#              5                   0.000     0.000
#              6                   0.000     0.000
#              7                   0.000     0.000
#              8                   0.000     0.000
#              9                   0.000     0.000
#              10                  0.000     0.000
#              11                  0.000     0.000
#              12                  0.000     0.000
# 2019         1                   0.000     0.000
#              2                   0.000     0.000
#              3                   0.000     0.000
#              4                   0.000     0.000
#              5                   0.000     0.000
#              6                   0.000     0.000
#              7                   0.000     0.000
#              8                   0.000     0.000
#              9                   0.000     0.000
#              10                  0.000     0.000
#              11               1504.500     0.000
#              12                  0.000     0.000
# 2020         1               11028.706     0.000
#              2                6318.450     0.000
#              3                   0.000     0.000
#              4                   0.000     0.000
#              5                   0.000     0.000
#              6                   0.000     0.000
#              7                   0.000     0.000
#              8                   0.000     0.000
#              9                4514.769     0.000
#              10               8756.365  2429.375
#              11                  0.000     0.000

# %%
# meses

mes = {1: 'Enero', 
2: 'Febrero',
3: 'Marzo',
4: 'Abril',
5: 'Mayo',
6: 'Junio',
7: 'Julio',
8: 'Agosto',
9: 'Septiembre',
10: 'Octubre',
11: 'Noviembre',
12: 'Diciembre'}

# %%
# Creamos los dataframes por año para filtrar

consumo2017 = ventasClienteTotal.loc[2017].rename(index=mes)
consumo2018 = ventasClienteTotal.loc[2018].rename(index=mes)
consumo2019 = ventasClienteTotal.loc[2019].rename(index=mes)
consumo2020 = ventasClienteTotal.loc[2020].rename(index=mes)
consumo2020
# Out:
# Especificaciones.calibreECT        23       26          29          32  \
# fechaEmision
# Enero                           0.000  3364.00  22153.7505  34926.9440
# Febrero                         0.000  1682.00   4270.2305  18004.7715
# Marzo                           0.000  3364.00      0.0000  40733.2700
# Abril                           0.000  1682.00   2410.0170  14336.3550
# Mayo                            0.000  3364.00      0.0000  28672.7100
# Junio                           0.000  1682.00   1169.6360  17566.1850
# Julio                           0.000  3869.85   1421.1160  32309.7350
# Agosto                          0.000  1682.00      0.0000  16417.8405
# Septiembre                      0.000  1682.00  13450.5295  25254.5461
# Octubre                      7695.515  3364.00   1259.2400  33378.8515
# Noviembre                       0.000     0.00   4516.2000  53269.3640
#
# Especificaciones.calibreECT         36        38
# fechaEmision
# Enero                        11028.706     0.000
# Febrero                       6318.450     0.000
# Marzo                            0.000     0.000
# Abril                            0.000     0.000
# Mayo                             0.000     0.000
# Junio                            0.000     0.000
# Julio                            0.000     0.000
# Agosto                           0.000     0.000
# Septiembre                    4514.769     0.000
# Octubre                       8756.365  2429.375
# Noviembre                        0.000     0.000

# %%
# Iniciamos con la construcción del grafico dividido

sns.set_style('white')
fig = plt.figure(figsize=(80, 200))
plt.title('Total de m2 por calibre suministrados por año', fontsize=30, y=1.05)
plt.axis('off')
plt.rc('xtick',labelsize=15)
plt.rc('ytick',labelsize=20)

# Deshabilitamos compartir axis ya que los datos son muy diferentes por la entrada de clientes nuevos y 

axes = fig.subplots(2, 2, sharex=False, sharey=False)

ax1 = consumo2017.plot(kind="bar", figsize=(20, 20), ax=axes[0, 0], grid=True)
ax2 = consumo2018.plot(kind="bar", figsize=(20, 20), ax=axes[0, 1], grid=True)
ax3 = consumo2019.plot(kind="bar", figsize=(20, 20), ax=axes[1, 0], grid=True)
ax4 = consumo2020.plot(kind="bar", figsize=(20, 20), ax=axes[1, 1], grid=True)


# Añadimos descripciones y formato
ax1.set_ylabel('m2 utilizados', fontsize=20)
ax1.set_xlabel('mes').set_visible(False)
ax1.set_title('2017', fontsize=30)
ax2.set_ylabel('m2 utilizados', fontsize=20)
ax2.set_xlabel('mes').set_visible(False)
ax2.set_title('2018', fontsize=30)
ax2.set_ylabel('mes').set_visible(False)
ax3.set_ylabel('m2 utilizados', fontsize=20)
ax3.set_title('2019', fontsize=30)
ax3.set_xlabel('mes').set_visible(False)
ax3.set_yticks(np.arange(0, 45000, step=5000))
ax4.set_ylabel('m2 utilizados', fontsize=20)
ax4.set_title('2020', fontsize=30)
ax4.set_xlabel('mes').set_visible(False)
ax4.set_yticks(np.arange(0, 55000, step=5000))
ax4.set_ylabel('mes').set_visible(False)

plt.savefig("../recursos/volumenxCalibre.png")

# %% [markdown]
# Es visible lo siguiente:
#
# * El volumen por calibre fue incrementando y diversificado donde el aumento en la demanda es evidente. Por tres años el consumo minimo del corrugado de 32 ECT fue minimo de 15000 m2 al mes mientras los otros calibres se mantuvieron por debajo de 5000 m2. El valor maximo fue superior a 25,000 m2.
#
# * Esta tendencia cambio desde finales del 2019 con la entrada de nuevos clientes y aumento en las ventas. El resto de los formatos mantuvieron una tendencia por debajo de 10000 m2 por lo que podemos concluir lo siguiente:
#
# * La tendencia para este año nos muestra las siguientes recomendaciones:
#
#     * Se recomienda mantener un nivel de inventario en el corrugado de 32 ECT de al menos 20000 m2 para sostener los pedidos más grandes.
#
#     * Se recomienda mantener un nivel de 5000 m2 en el resto de los otros calibres para evitar retrasos en la entrega del equipo por mes.
