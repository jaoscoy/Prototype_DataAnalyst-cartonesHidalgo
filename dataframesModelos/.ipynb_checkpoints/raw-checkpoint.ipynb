# %% [markdown]
# # Construcción del dataframe base

# %% [markdown]
# ##### A partir los archivos JSON guardados en la base de datos, crear un dataframe modelo como base para el análisis de datos, creación de graficas y herramientas.

# %%
# Importamos las librerias necesarias

import pandas as pd
import certifi
import pymongo as py

# %%
# Creamos una variable con la conexion a la base de datos. 

from pymongo import MongoClient
cartonadoradores = MongoClient('mongodb+srv://introabd:introabd1234@cluster0.yx5qd.mongodb.net/?retryWrites=true&w=majority')

# Seleccionamos la BD previamente creada en mongo shell y con las validaciones ya configuradas.

df = cartonadoradores['cartonadoradores']

# %%
# Importamos todas las coleeciones de las que obtenemos información.

usuarios = df['Usuarios']
productos = df['Productos']
ordenes = df['ordenesCompra']

# %%
# Todas las colecciones son recibidas como archivos JSON

for x in usuarios.find():
    print (x)
# Out:
# {'_id': ObjectId('5fba998a345a4bb6ed3446c8'), 'apellidoContacto': 'Gonzalez Martinez', 'nombreContacto': 'Enrique', 'email': 'onoYoko@dominio.com', 'calle': 'Dr. Enrique Gonzalez Martinez No. 6 Local ', 'numero': 'No.6 Local 1', 'alcaldia_municipio': 'Cuahutemoc', 'ciudad': 'CDMX', 'cp': 6400, 'rfc': 'LOQ640401GH0', 'nivelAcceso': 'cliente', 'razonSocial': 'LOQUAY. S.A.'}
# {'_id': ObjectId('5fbb2a25169e8c0534716100'), 'apellidoContacto': 'Rodriguez  ', 'nombreContacto': 'Rosario', 'email': 'facturaciones@covadonga.com.mx', 'calle': 'Aldana', 'numero': 'No. 43', 'alcaldia_municipio': 'Texcoco', 'ciudad': 'Estado de México', 'cp': 56170, 'rfc': 'CCO810311660', 'nivelAcceso': 'cliente', 'razonSocial': 'CREMERIA COVADONGA S.A. DE C.V.'}
# {'_id': ObjectId('5fbb463ad94852d0d6906924'), 'apellidoContacto': 'Parangueo', 'nombreContacto': 'Norma', 'email': 'invernaderos@izi.com.mx', 'calle': 'Jaime Torres Bodet', 'numero': 'No. 16', 'alcaldia_municipio': 'Zitacuaro', 'ciudad': 'Michoacán', 'cp': 61513, 'rfc': 'OOge30402', 'nivelAcceso': 'cliente', 'razonSocial': 'Invernaderos de Zitácuaro, S. de R.L.'}
# {'_id': ObjectId('5fbb48fbd94852d0d6906925'), 'apellidoContacto': 'Aamilla Martinez', 'nombreContacto': 'Veronica', 'email': 'chicaPlastica@siembra.com.mx', 'calle': 'Prolongación ciprés', 'numero': 'N.ext 3998', 'alcaldia_municipio': 'Azcapotzalco', 'ciudad': 'CDMX', 'cp': 2970, 'rfc': 'PLA970124IKA', 'nivelAcceso': 'cliente', 'razonSocial': 'PLASTONIUM, S.A DE C.V.'}
# {'_id': ObjectId('5fbb56b3cfeb74a0ee851d57'), 'apellidoContacto': 'Intermuebles', 'nombreContacto': 'Modulares', 'email': 'mobiliario@modular.com.mx', 'calle': 'Av. Lomas de sotelo', 'numero': 'No. 1102 Piso 2 202', 'alcaldia_municipio': 'Miguel hidalgo', 'ciudad': 'CDMX', 'cp': 11200, 'rfc': 'IMA191187OO8', 'nivelAcceso': 'cliente', 'razonSocial': 'Intermuebles Modulares, S.A. de C.V.'}

# %%
    # En una variable asignamos el codigo pipeline que indica las agregaciones necesarias para crear nuestro dataset
    # a través de una vista

pipeline = [
    {
        '$unwind': {
            'path': '$Productos'
        }
    }, {
        '$lookup': {
            'from': 'Productos', 
            'localField': 'Productos.idProducto', 
            'foreignField': '_id', 
            'as': 'Especificaciones'
        }
    }, {
        '$unwind': {
            'path': '$Especificaciones'
        }
    }, {
        '$lookup': {
            'from': 'Usuarios', 
            'localField': 'idUsuario', 
            'foreignField': '_id', 
            'as': 'Usuario'
        }
    }, {
        '$unwind': {
            'path': '$Usuario'
        }
    }, {
        '$addFields': {
            'priceKey': {
                '$concat': [
                    {
                        '$toString': '$Especificaciones.calibreECT'
                    }, '$Especificaciones.tipo', '$Especificaciones.caraExterior'
                ]
            }
        }
    }]

# %% [markdown]
# Por medio del metodo _.aggregate()_, ejecutamos las agregaciones con la variable el pipeline como parametro.
#
# Usamos el metodo _json_normalize()_ para convertir la lista en un dataframe con un registro por cada producto vendido en cada orden.

# %%
dfJSON = list(df.ordenesCompra.aggregate(pipeline))
operaciones = pd.json_normalize(dfJSON)

# %% [markdown]
# Usamos el metodo _.groupby()_ para mostrar los clientes existentes y usar la información en los filtros siguientes.

# %%
operaciones.groupby('Usuario.razonSocial').last()

# %%
operaciones.columns

# %% [markdown]
# Creamos un dataframe filtrado por compañia para doble checar los detalles de las ordenes de compra por cada cliente y verificar que no haya repetidos

# %%
prueba = operaciones['Usuario.razonSocial'] == 'LOQUAY. S.A.'

#operaciones[prueba].groupby('foliointerno')[['_id','Especificaciones.calibreECT','Especificaciones.largo',
 #     'Especificaciones.ancho', 'Especificaciones.alto','Productos.precioUnitario', 'Especificaciones.descripcion', 'Productos.idProducto']].last()
    
operaciones.groupby(['Usuario.razonSocial']).agg({'_id': 'count', 'Productos.importe':'sum', 'Productos.cantidad': 'sum', 'Productos.idLocal': 'count'})
# Out:
#                                        _id  Productos.importe  \
# Usuario.razonSocial
# CREMERIA COVADONGA S.A. DE C.V.        108          6494525.0
# Intermuebles Modulares, S.A. de C.V.    29           991275.0
# Invernaderos de Zitácuaro, S. de R.L.   12           867600.0
# LOQUAY. S.A.                            79          1455258.0
# PLASTONIUM, S.A DE C.V.                  9           145700.0
#
#                                        Productos.cantidad  Productos.idLocal
# Usuario.razonSocial
# CREMERIA COVADONGA S.A. DE C.V.                   540.000                108
# Intermuebles Modulares, S.A. de C.V.               20.725                 29
# Invernaderos de Zitácuaro, S. de R.L.              48.000                 12
# LOQUAY. S.A.                                      226.000                 79
# PLASTONIUM, S.A DE C.V.                            25.500                  9

# %% [markdown]
# Usamos el metodo _groupby()_ sobre el dataframe de prueba para verificar que los productos asociados a cada cliente no se repitan y esten correctamente ordenados con las caracteristicas correctas.

# %%
operaciones[prueba].groupby('Productos.idProducto')[['_id', 'Productos.idLocal', 'Especificaciones.calibreECT','Especificaciones.largo', \
'Especificaciones.ancho', 'Especificaciones.alto','Productos.precioUnitario', 'Especificaciones.descripcion', 'Productos.idProducto']].last()
# Out:
#                                                _id Productos.idLocal  \
# Productos.idProducto
# 5fc3d5a130024fb085af64ab  5fcbf3144124c8597eb6c910             CJ246
# 5fc3dad730024fb085af64ac  5fcbed554124c8597eb6c8ff             CJ245
# 5fc3dd7e30024fb085af64ad  5fcbdc7e4124c8597eb6c8e3             CJ247
# 5fc3df6630024fb085af64ae  5fcbf1c14124c8597eb6c90b              CJ65
# 5fc3e05030024fb085af64af  5fcbf24f4124c8597eb6c90d              CJ67
# 5fc3e18e30024fb085af64b0  5fcbf2174124c8597eb6c90c              CJ90
# 5fc3e2df30024fb085af64b1  5fcbecf24124c8597eb6c8fe             CJ186
# 5fc3e34730024fb085af64b2  5fcbef774124c8597eb6c905              CJ42
# 5fc3e3ef30024fb085af64b3  5fcbe9ae4124c8597eb6c8f9              CJ22
# 5fc9d818450966d58fee1ef3  5fcbdfe14124c8597eb6c8e9              CJ08
# 5fc9d875450966d58fee1ef4  5fcbed9a4124c8597eb6c900              CJ61
# 5fc9d8ef450966d58fee1ef5  5fcbea8d4124c8597eb6c8fb              CJ98
# 5fc9d977450966d58fee1ef6  5fcbf2e24124c8597eb6c90f              CJ85
# 5fc9d9dc450966d58fee1ef7  5fcbf28a4124c8597eb6c90e             CJ249
# 5fc9da2c450966d58fee1ef8  5fcbe7b24124c8597eb6c8f2              CJ07
# 5fc9daa6450966d58fee1ef9  5fcbf1504124c8597eb6c909              CJ05
# 5fc9db83450966d58fee1efa  5fcbe92b4124c8597eb6c8f7             CJ227
# 5fcb964f6966fe2679e7feaa  5fcbead74124c8597eb6c8fc              CJ60
# 5fcbda2b6966fe2679e7feac  5fcbf0f24124c8597eb6c908              CJ04
# 5fcbdbd56966fe2679e7fead  5fcbf16e4124c8597eb6c90a              CJ09
# 5fcbe4456966fe2679e7feae  5fcbe5e24124c8597eb6c8ed             CJ225
# 5fcbe64b6966fe2679e7feaf  5fcbe6594124c8597eb6c8ee             CJ223
# 5fcbe8d76966fe2679e7feb0  5fcbe8ec4124c8597eb6c8f6             CJ201
# 5fcbe9fc6966fe2679e7feb1  5fcbea224124c8597eb6c8fa              CJ35
# 5fcbee796966fe2679e7feb3  5fcbeea04124c8597eb6c902              CJ62
# 5fcbeef26966fe2679e7feb4  5fcbef234124c8597eb6c903             CJ239
# 5fcbefb66966fe2679e7feb5  5fcbefe84124c8597eb6c906              CJ58
# 5fcbf09a6966fe2679e7feb6  5fcbf0b64124c8597eb6c907              CJ03
#
#                           Especificaciones.calibreECT  Especificaciones.largo  \
# Productos.idProducto
# 5fc3d5a130024fb085af64ab                           32                    32.3
# 5fc3dad730024fb085af64ac                           29                    19.6
# 5fc3dd7e30024fb085af64ad                           32                    44.3
# 5fc3df6630024fb085af64ae                           29                    20.0
# 5fc3e05030024fb085af64af                           29                    26.3
# 5fc3e18e30024fb085af64b0                           29                    20.0
# 5fc3e2df30024fb085af64b1                           29                    19.0
# 5fc3e34730024fb085af64b2                           29                    25.2
# 5fc3e3ef30024fb085af64b3                           32                    26.0
# 5fc9d818450966d58fee1ef3                           29                    28.0
# 5fc9d875450966d58fee1ef4                           29                    29.0
# 5fc9d8ef450966d58fee1ef5                           29                    32.3
# 5fc9d977450966d58fee1ef6                           29                    19.6
# 5fc9d9dc450966d58fee1ef7                           36                    32.8
# 5fc9da2c450966d58fee1ef8                           32                    33.8
# 5fc9daa6450966d58fee1ef9                           36                    30.5
# 5fc9db83450966d58fee1efa                           29                    34.0
# 5fcb964f6966fe2679e7feaa                           29                    29.0
# 5fcbda2b6966fe2679e7feac                           36                    32.3
# 5fcbdbd56966fe2679e7fead                           36                    48.3
# 5fcbe4456966fe2679e7feae                           26                    19.0
# 5fcbe64b6966fe2679e7feaf                           29                    27.2
# 5fcbe8d76966fe2679e7feb0                           29                    21.0
# 5fcbe9fc6966fe2679e7feb1                           32                    48.7
# 5fcbee796966fe2679e7feb3                           29                    29.0
# 5fcbeef26966fe2679e7feb4                           29                    29.0
# 5fcbefb66966fe2679e7feb5                           29                    19.0
# 5fcbf09a6966fe2679e7feb6                           36                    27.7
#
#                           Especificaciones.ancho  Especificaciones.alto  \
# Productos.idProducto
# 5fc3d5a130024fb085af64ab                    24.5                   30.3
# 5fc3dad730024fb085af64ac                    15.0                   17.5
# 5fc3dd7e30024fb085af64ad                    32.0                   14.5
# 5fc3df6630024fb085af64ae                    10.4                   18.5
# 5fc3e05030024fb085af64af                    17.8                   13.2
# 5fc3e18e30024fb085af64b0                    10.4                   18.5
# 5fc3e2df30024fb085af64b1                    12.7                   18.6
# 5fc3e34730024fb085af64b2                    23.5                   19.0
# 5fc3e3ef30024fb085af64b3                    19.5                   20.0
# 5fc9d818450966d58fee1ef3                    21.2                   18.5
# 5fc9d875450966d58fee1ef4                    20.5                   16.3
# 5fc9d8ef450966d58fee1ef5                    18.5                   13.3
# 5fc9d977450966d58fee1ef6                    15.0                   20.0
# 5fc9d9dc450966d58fee1ef7                    25.0                   25.3
# 5fc9da2c450966d58fee1ef8                    30.8                   30.0
# 5fc9daa6450966d58fee1ef9                    30.5                   27.0
# 5fc9db83450966d58fee1efa                    18.2                   14.7
# 5fcb964f6966fe2679e7feaa                    20.5                   16.3
# 5fcbda2b6966fe2679e7feac                    24.5                   27.5
# 5fcbdbd56966fe2679e7fead                    33.5                   14.5
# 5fcbe4456966fe2679e7feae                    16.0                   16.0
# 5fcbe64b6966fe2679e7feaf                    24.8                   14.2
# 5fcbe8d76966fe2679e7feb0                    19.0                   23.7
# 5fcbe9fc6966fe2679e7feb1                    30.7                   15.9
# 5fcbee796966fe2679e7feb3                    20.5                   16.3
# 5fcbeef26966fe2679e7feb4                    20.5                   16.3
# 5fcbefb66966fe2679e7feb5                    12.7                   18.6
# 5fcbf09a6966fe2679e7feb6                    20.7                   21.2
#
#                           Productos.precioUnitario  \
# Productos.idProducto
# 5fc3d5a130024fb085af64ab                   10600.0
# 5fc3dad730024fb085af64ac                    3536.0
# 5fc3dd7e30024fb085af64ad                   13832.0
# 5fc3df6630024fb085af64ae                    2756.0
# 5fc3e05030024fb085af64af                    4191.0
# 5fc3e18e30024fb085af64b0                    2756.0
# 5fc3e2df30024fb085af64b1                    3089.0
# 5fc3e34730024fb085af64b2                    6178.0
# 5fc3e3ef30024fb085af64b3                   12730.0
# 5fc9d818450966d58fee1ef3                    5845.0
# 5fc9d875450966d58fee1ef4                    5512.0
# 5fc9d8ef450966d58fee1ef5                    4846.0
# 5fc9d977450966d58fee1ef6                    3744.0
# 5fc9d9dc450966d58fee1ef7                   10088.0
# 5fc9da2c450966d58fee1ef8                   14113.0
# 5fc9daa6450966d58fee1ef9                   12012.0
# 5fc9db83450966d58fee1efa                    5054.0
# 5fcb964f6966fe2679e7feaa                    5512.0
# 5fcbda2b6966fe2679e7feac                   10088.0
# 5fcbdbd56966fe2679e7fead                   13343.0
# 5fcbe4456966fe2679e7feae                    3422.0
# 5fcbe64b6966fe2679e7feaf                    6063.0
# 5fcbe8d76966fe2679e7feb0                   10360.0
# 5fcbe9fc6966fe2679e7feb1                   12688.0
# 5fcbee796966fe2679e7feb3                    5512.0
# 5fcbeef26966fe2679e7feb4                    5512.0
# 5fcbefb66966fe2679e7feb5                    3193.0
# 5fcbf09a6966fe2679e7feb6                    6396.0
#
#                                          Especificaciones.descripcion  \
# Productos.idProducto
# 5fc3d5a130024fb085af64ab                         Corrugado 12 SH 1 LT
# 5fc3dad730024fb085af64ac                          Corrugado 12 remove
# 5fc3dd7e30024fb085af64ad                          Corrugado 24 VELLOS
# 5fc3df6630024fb085af64ae       Corrugado primer PULVER AZUL 12 piezas
# 5fc3e05030024fb085af64af                             Corrugado 24 RPQ
# 5fc3e18e30024fb085af64b0            CORRUGADO PULVER BLANCO 12 PIEZAS
# 5fc3e2df30024fb085af64b1                 CORRUGADO TINTA COLOR 12 ETC
# 5fc3e34730024fb085af64b2                             CORRUGADO 30 ECT
# 5fc3e3ef30024fb085af64b3                             CORRUGADO 30 ECT
# 5fc9d818450966d58fee1ef3          corrugado 30-36/120/50 "PULVER 50G"
# 5fc9d875450966d58fee1ef4  corrugado special primer men castaño oscuro
# 5fc9d8ef450966d58fee1ef5                             corrugado 12 EAT
# 5fc9d977450966d58fee1ef6                              Corrugado 12 MT
# 5fc9d9dc450966d58fee1ef7                       Corrugado 12-perox-1LT
# 5fc9da2c450966d58fee1ef8                          CORRUGADO 18-24/350
# 5fc9daa6450966d58fee1ef9                            CORRUGADO 100/120
# 5fc9db83450966d58fee1efa                        CORRUGADO LACIO RIZOS
# 5fcb964f6966fe2679e7feaa           CORRUGADO SPECIAL PRIMER MEN NEGRO
# 5fcbda2b6966fe2679e7feac                         CORRUGADO 12 OND 1LT
# 5fcbdbd56966fe2679e7fead                           CORRUGADO 10-20-24
# 5fcbe4456966fe2679e7feae        CORRUGADO TRATAMIENTO AMINO 12 PIEZAS
# 5fcbe64b6966fe2679e7feaf                              CORRUGADO 120ML
# 5fcbe8d76966fe2679e7feb0                        CORRUGADO 12 CHOC 300
# 5fcbe9fc6966fe2679e7feb1                             CORRUGADO 30 MEN
# 5fcbee796966fe2679e7feb3         CORRUGADO SPECIAL PRIMER MEN CASTAÑO
# 5fcbeef26966fe2679e7feb4   CORRUGADO SPECIAL PRIMER MEN CASTAÑO CLARO
# 5fcbefb66966fe2679e7feb5      CORRUGADO 12-PC PIEZAS DE TUBO DE TINTE
# 5fcbf09a6966fe2679e7feb6                             CORRUGADO 14 KIT
#
#                               Productos.idProducto
# Productos.idProducto
# 5fc3d5a130024fb085af64ab  5fc3d5a130024fb085af64ab
# 5fc3dad730024fb085af64ac  5fc3dad730024fb085af64ac
# 5fc3dd7e30024fb085af64ad  5fc3dd7e30024fb085af64ad
# 5fc3df6630024fb085af64ae  5fc3df6630024fb085af64ae
# 5fc3e05030024fb085af64af  5fc3e05030024fb085af64af
# 5fc3e18e30024fb085af64b0  5fc3e18e30024fb085af64b0
# 5fc3e2df30024fb085af64b1  5fc3e2df30024fb085af64b1
# 5fc3e34730024fb085af64b2  5fc3e34730024fb085af64b2
# 5fc3e3ef30024fb085af64b3  5fc3e3ef30024fb085af64b3
# 5fc9d818450966d58fee1ef3  5fc9d818450966d58fee1ef3
# 5fc9d875450966d58fee1ef4  5fc9d875450966d58fee1ef4
# 5fc9d8ef450966d58fee1ef5  5fc9d8ef450966d58fee1ef5
# 5fc9d977450966d58fee1ef6  5fc9d977450966d58fee1ef6
# 5fc9d9dc450966d58fee1ef7  5fc9d9dc450966d58fee1ef7
# 5fc9da2c450966d58fee1ef8  5fc9da2c450966d58fee1ef8
# 5fc9daa6450966d58fee1ef9  5fc9daa6450966d58fee1ef9
# 5fc9db83450966d58fee1efa  5fc9db83450966d58fee1efa
# 5fcb964f6966fe2679e7feaa  5fcb964f6966fe2679e7feaa
# 5fcbda2b6966fe2679e7feac  5fcbda2b6966fe2679e7feac
# 5fcbdbd56966fe2679e7fead  5fcbdbd56966fe2679e7fead
# 5fcbe4456966fe2679e7feae  5fcbe4456966fe2679e7feae
# 5fcbe64b6966fe2679e7feaf  5fcbe64b6966fe2679e7feaf
# 5fcbe8d76966fe2679e7feb0  5fcbe8d76966fe2679e7feb0
# 5fcbe9fc6966fe2679e7feb1  5fcbe9fc6966fe2679e7feb1
# 5fcbee796966fe2679e7feb3  5fcbee796966fe2679e7feb3
# 5fcbeef26966fe2679e7feb4  5fcbeef26966fe2679e7feb4
# 5fcbefb66966fe2679e7feb5  5fcbefb66966fe2679e7feb5
# 5fcbf09a6966fe2679e7feb6  5fcbf09a6966fe2679e7feb6

# %% [markdown]
# Una vez limpio el dataset lo exportamos con el metodo _.to_csv_ para ubicarlo y utilizarlo facilmente

# %%
operaciones.to_csv('operaciones.csv')
